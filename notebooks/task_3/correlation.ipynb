# %%
import sys
import os
import talib 

# Go two levels up: from 'notebooks/task1/' to the project root
sys.path.append(os.path.abspath(os.path.join('..', '..')))

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\ABC\Desktop\10Acadamy\week1\analysis-of-financial-news-data\data\final\financial_data_with_return.csv')

# %%
from src.correlation import compute_daily_sentiment_correlation,plot_correlation_bar,plot_scatter_sentiment_vs_return
results = compute_daily_sentiment_correlation(df)
print(results)
# Out:
#    stock  correlation_sentiment_return  n_days
# 0   AAPL                     -0.060436      61
# 1   AMZN                      0.080046      28
# 2    FXI                      0.031646      78
# 3   GOOG                      0.054008     352
# 4  GOOGL                      0.016827     423
# 5    INO                      0.065097     454
# 6   NFLX                      0.136599     782
# 7   NVDA                      0.143281    1125
# 8   TSLA                      0.167539     230
# 9    UAL                      0.168903     297

# %%
plot_correlation_bar(results)
# Out:
# c:\Users\ABC\Desktop\10Acadamy\week1\analysis-of-financial-news-data\src\correlation.py:46: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
plot_scatter_sentiment_vs_return(df, stock_name='GOOG')
# Out:
# Unique sentiment values (after clean): ['positive' 'neutral' 'negative']
# Unique numeric sentiment values: [ 1  0 -1]
# Stock rows: (1168, 19)
# After dropping NA: (1168, 19)
# Grouped daily shape: (352, 2)
#             avg_sentiment  avg_return
# date
# 2018-11-13           0.50       -0.69
# 2018-11-14           0.50       -0.60
# 2018-11-15          -0.25        1.91
# 2018-11-16           0.00        0.20
# 2018-11-19          -1.00       -3.52
