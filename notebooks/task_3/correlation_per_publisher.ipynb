# %%
import sys
import os
import talib 

# Go two levels up: from 'notebooks/task1/' to the project root
sys.path.append(os.path.abspath(os.path.join('..', '..')))

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\ABC\Desktop\10Acadamy\week1\analysis-of-financial-news-data\data\final\financial_data_with_return.csv')

# %%
from src.correlation import compute_daily_sentiment_correlation,plot_correlation_bar,plot_scatter_sentiment_vs_return
results = compute_daily_sentiment_correlation(df)
print(results)
# Out:
#    stock  correlation_sentiment_return  n_days
# 0   AAPL                     -0.060436      61
# 1   AMZN                      0.080046      28
# 2    FXI                      0.031646      78
# 3   GOOG                      0.054008     352
# 4  GOOGL                      0.016827     423
# 5    INO                      0.065097     454
# 6   NFLX                      0.136599     782
# 7   NVDA                      0.143281    1125
# 8   TSLA                      0.167539     230
# 9    UAL                      0.168903     297

# %%
plot_correlation_bar(results)
# Out:
# c:\Users\ABC\Desktop\10Acadamy\week1\analysis-of-financial-news-data\src\correlation.py:46: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
from src.correlation import compute_daily_sentiment_correlation_by_publisher
# Compute correlation per publisher, per stock
corr_pub_df = compute_daily_sentiment_correlation_by_publisher(df)

# To plot, you might want to filter by publisher:
selected_publisher = "Benzinga Newsdesk"
benzinga_corr = corr_pub_df[corr_pub_df['publisher'] == selected_publisher]

# Plot correlation for this publisher
plot_correlation_bar(benzinga_corr)
# Out:
# c:\Users\ABC\Desktop\10Acadamy\week1\analysis-of-financial-news-data\venv\Lib\site-packages\numpy\lib\_function_base_impl.py:3037: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# c:\Users\ABC\Desktop\10Acadamy\week1\analysis-of-financial-news-data\venv\Lib\site-packages\numpy\lib\_function_base_impl.py:2894: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# c:\Users\ABC\Desktop\10Acadamy\week1\analysis-of-financial-news-data\venv\Lib\site-packages\numpy\lib\_function_base_impl.py:2894: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# c:\Users\ABC\Desktop\10Acadamy\week1\analysis-of-financial-news-data\venv\Lib\site-packages\numpy\lib\_function_base_impl.py:3045: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# ...

# %%
# To plot, you might want to filter by publisher:
selected_publisher = "Paul Quintaro"
Paul_corr = corr_pub_df[corr_pub_df['publisher'] == selected_publisher]

# Plot correlation for this publisher
plot_correlation_bar(Paul_corr)
# Out:
# c:\Users\ABC\Desktop\10Acadamy\week1\analysis-of-financial-news-data\src\correlation.py:46: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
# To plot, you might want to filter by publisher:
selected_publisher = "Lisa Levin"
Lisa_corr = corr_pub_df[corr_pub_df['publisher'] == selected_publisher]

# Plot correlation for this publisher
plot_correlation_bar(Lisa_corr)
# Out:
# c:\Users\ABC\Desktop\10Acadamy\week1\analysis-of-financial-news-data\src\correlation.py:46: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
# To plot, you might want to filter by publisher:
selected_publisher = "Charles Gross"
Charles_corr = corr_pub_df[corr_pub_df['publisher'] == selected_publisher]

# Plot correlation for this publisher
plot_correlation_bar(Charles_corr)
# Out:
# c:\Users\ABC\Desktop\10Acadamy\week1\analysis-of-financial-news-data\src\correlation.py:46: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
from src.correlation import plotly_correlation_bar_by_stock
plotly_correlation_bar_by_stock(corr_pub_df, stock="AMZN")

# %%
from src.correlation import plotly_correlation_bar_by_stock
plotly_correlation_bar_by_stock(corr_pub_df, stock="GOOG")

# %%
from src.correlation import plotly_correlation_bar_by_stock
plotly_correlation_bar_by_stock(corr_pub_df, stock="NVDA")

# %%
from src.correlation import plotly_correlation_bar_by_stock
plotly_correlation_bar_by_stock(corr_pub_df, stock="TSLA")

# %%
from src.correlation import plotly_correlation_bar_by_stock
plotly_correlation_bar_by_stock(corr_pub_df, stock="MSFT")
# Out:
# No strong correlations for stock 'MSFT'.
